# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('concrete_data.csv')

# %%
df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
X=df.drop(columns=['Strength'])
y=df['Strength']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=90)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)
print('acc score',r2_score(y_test,y_pred))
# Out:
# acc score 0.574066071464593

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt_box_cox=PowerTransformer(method='yeo-johnson')

# %%
X_train.head()
# Out:
#      Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 501   491.0                26.0    123.0  210.0               3.9
# 162   374.0               189.2      0.0  170.1              10.1
# 496   387.0                20.0     94.0  157.0              11.6
# 30    304.0                76.0      0.0  228.0               0.0
# 436   172.4                13.6    172.4  156.8               4.1
#
#      Coarse Aggregate  Fine Aggregate  Age
# 501             882.0           699.0    3
# 162             926.1           756.7   91
# 496             938.0           845.0   56
# 30              932.0           670.0  365
# 436            1006.3           856.4   28

# %%
X_train_new=X_train.drop(columns=['Superplasticizer','Blast Furnace Slag','Fly Ash'])
X_test_new=X_test.drop(columns=['Superplasticizer','Blast Furnace Slag','Fly Ash'])

# %%
X_train_new
# Out:
#      Cement  Water  Coarse Aggregate  Fine Aggregate  Age
# 501   491.0  210.0             882.0           699.0    3
# 162   374.0  170.1             926.1           756.7   91
# 496   387.0  157.0             938.0           845.0   56
# 30    304.0  228.0             932.0           670.0  365
# 436   172.4  156.8            1006.3           856.4   28
# ..      ...    ...               ...             ...  ...
# 570   295.8  185.7            1091.4           769.3   28
# 452   173.8  172.3            1007.2           746.6   56
# 679   212.0  203.5             973.4           750.0   28
# 671   236.0  192.0             972.6           749.1    7
# 669   288.0  192.0             932.0           717.8    3
#
# [824 rows x 5 columns]

# %%
X_train_new.describe()
# Out:
#            Cement       Water  Coarse Aggregate  Fine Aggregate         Age
# count  824.000000  824.000000        824.000000      824.000000  824.000000
# mean   279.638714  181.375850        973.165170      773.858981   44.216019
# std    102.867626   21.316125         77.722554       80.229106   60.392977
# min    102.000000  121.800000        801.000000      594.000000    1.000000
# 25%    193.500000  164.900000        932.000000      734.000000    7.000000
# 50%    269.400000  185.000000        968.000000      780.000000   28.000000
# 75%    349.250000  192.000000       1032.750000      825.000000   56.000000
# max    540.000000  247.000000       1145.000000      992.600000  365.000000

# %%
X_train_trans=pt_box_cox.fit_transform(X_train_new)
X_test_trans=pt_box_cox.fit(X_test_new)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1760\1984056176.py in <module>
# ----> 1 X_train_trans=pt_box_cox.fit_transform(X_train_new)
#       2 X_test_trans=pt_box_cox.fit(X_test_new)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit_transform(self, X, y)
#    3063             Transformed data.
#    3064         """
# -> 3065         return self._fit(X, y, force_transform=True)
#    3066
#    3067     def _fit(self, X, y=None, force_transform=False):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in _fit(self, X, y, force_transform)
#    3066
#    3067     def _fit(self, X, y=None, force_transform=False):
# -> 3068         X = self._check_input(X, in_fit=True, check_positive=True, check_method=True)
#    3069
#    3070         if not self.copy and not force_transform:  # if call from fit()
#
# ...
